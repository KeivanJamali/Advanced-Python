# %%
# %load_ext autoreload
# %autoreload 2

# %%
from DataLoader import Graph_Generator
from Players import Intersection

# %%
import simpy

# %%
graph = Graph_Generator(network_file=r"/mnt/Data1/Python_Projects/Machine-Learning-Projects/Project 13 - Saghar Ahmadi/data/Network.csv")

# %%
graph.draw()

# %%
i1 = Intersection(simpy.Environment(), node_id=9, neighbors=[8, 10, 5])

# %%
i1.servers
# Out:
# [[<Players.MovementServerIntersection at 0x7d733e1bb350>,
# ...
