# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from pathlib import Path
from Engine import Clock

# %%
demand_path = r"/mnt/Data1/Python_Projects/Advanced-Python/Project-02-AV-Simulation/data/demand.csv"
network_file = r"/mnt/Data1/Python_Projects/Advanced-Python/Project-02-AV-Simulation/data/Network.csv"
pos_file = r"/mnt/Data1/Python_Projects/Advanced-Python/Project-02-AV-Simulation/data/SiouxFalls_node_xy.tntp"
output_directory = r"/mnt/Data1/Python_Projects/Advanced-Python/Project-02-AV-Simulation/Results"
network_files = [network_file, pos_file]
world = Clock(network_files=network_files, dedicated_lane_length=500, lane_changing_zone_length=500, output_directory=output_directory)
world.draw_network()
# Out:
# [INFO] Intersection 1 initialized with these lanes: {'2': [<Players.Lane object at 0x70b1f06e31d0>, <Players.Lane object at 0x70b1f06e29d0>, <Players.Lane object at 0x70b1f06e0350>, <Players.Lane object at 0x70b1f06e0dd0>, <Players.Lane object at 0x70b1f06e0cd0>], '3': [<Players.Lane object at 0x70b1f06e1f50>, <Players.Lane object at 0x70b1f06e1fd0>, <Players.Lane object at 0x70b1f06e0d50>, <Players.Lane object at 0x70b1f06e1e50>, <Players.Lane object at 0x70b1f06e2b50>]}.
# [INFO] Intersection 2 initialized with these lanes: {'1': [<Players.Lane object at 0x70b1f06e2ad0>, <Players.Lane object at 0x70b1f06e2a50>, <Players.Lane object at 0x70b1f06e2650>, <Players.Lane object at 0x70b1f06e26d0>, <Players.Lane object at 0x70b1f06e28d0>], '6': [<Players.Lane object at 0x70b1f06e1d50>, <Players.Lane object at 0x70b1f06e1c50>, <Players.Lane object at 0x70b1f06e1bd0>, <Players.Lane object at 0x70b1f06e2850>, <Players.Lane object at 0x70b1f06e27d0>]}.
# [INFO] Intersection 3 initialized with these lanes: {'1': [<Players.Lane object at 0x70b1f06e2750>, <Players.Lane object at 0x70b1f06e2350>, <Players.Lane object at 0x70b1f06e23d0>, <Players.Lane object at 0x70b1f06e25d0>, <Players.Lane object at 0x70b1f06e03d0>], '4': [<Players.Lane object at 0x70b1f06e02d0>, <Players.Lane object at 0x70b1f06e0250>, <Players.Lane object at 0x70b1f06e0150>, <Players.Lane object at 0x70b1f06e2550>, <Players.Lane object at 0x70b1f06e24d0>], '12': [<Players.Lane object at 0x70b1f06e2450>, <Players.Lane object at 0x70b1f06e18d0>, <Players.Lane object at 0x70b1f06e1cd0>, <Players.Lane object at 0x70b1f06e22d0>, <Players.Lane object at 0x70b1f06e2250>]}.
# [INFO] Intersection 6 initialized with these lanes: {'2': [<Players.Lane object at 0x70b1f06e21d0>, <Players.Lane object at 0x70b1f06e1dd0>, <Players.Lane object at 0x70b1f06e1ed0>, <Players.Lane object at 0x70b1f06e1b50>, <Players.Lane object at 0x70b1f06e1950>], '5': [<Players.Lane object at 0x70b1f06e2150>, <Players.Lane object at 0x70b1f06e2050>, <Players.Lane object at 0x70b1f06e1ad0>, <Players.Lane object at 0x70b1f06e1a50>, <Players.Lane object at 0x70b1f06e19d0>], '8': [<Players.Lane object at 0x70b1f06e15d0>, <Players.Lane object at 0x70b1f06e1650>, <Players.Lane object at 0x70b1f06e1850>, <Players.Lane object at 0x70b1f06e0bd0>, <Players.Lane object at 0x70b1f06e0c50>]}.
# [INFO] Intersection 4 initialized with these lanes: {'3': [<Players.Lane object at 0x70b1f06e0550>, <Players.Lane object at 0x70b1f06e0ad0>, <Players.Lane object at 0x70b1f06e17d0>, <Players.Lane object at 0x70b1f06e1750>, <Players.Lane object at 0x70b1f06e16d0>], '5': [<Players.Lane object at 0x70b1f06e12d0>, <Players.Lane object at 0x70b1f06e1350>, <Players.Lane object at 0x70b1f06e1550>, <Players.Lane object at 0x70b1f06e09d0>, <Players.Lane object at 0x70b1f06e08d0>], '11': [<Players.Lane object at 0x70b1f06e0850>, <Players.Lane object at 0x70b1f06e14d0>, <Players.Lane object at 0x70b1f06e1450>, <Players.Lane object at 0x70b1f06e13d0>, <Players.Lane object at 0x70b1f06e0fd0>]}.
# [INFO] Intersection 12 initialized with these lanes: {'3': [<Players.Lane object at 0x70b1f06e1050>, <Players.Lane object at 0x70b1f06e1250>, <Players.Lane object at 0x70b1f06e11d0>, <Players.Lane object at 0x70b1f06e1150>, <Players.Lane object at 0x70b1f06e10d0>], '11': [<Players.Lane object at 0x70b1f06e00d0>, <Players.Lane object at 0x70b1f06e0950>, <Players.Lane object at 0x70b1f06e0f50>, <Players.Lane object at 0x70b1f06e0ed0>, <Players.Lane object at 0x70b1f06e0e50>], '13': [<Players.Lane object at 0x70b1f06e0a50>, <Players.Lane object at 0x70b1f06e07d0>, <Players.Lane object at 0x70b1f06e0b50>, <Players.Lane object at 0x70b1f06e0650>, <Players.Lane object at 0x70b1f06e2bd0>]}.
# [INFO] Intersection 5 initialized with these lanes: {'4': [<Players.Lane object at 0x70b1f06e20d0>, <Players.Lane object at 0x70b1f06e0750>, <Players.Lane object at 0x70b1f06e06d0>, <Players.Lane object at 0x70b1f06e01d0>, <Players.Lane object at 0x70b1f06e05d0>], '6': [<Players.Lane object at 0x70b1f06e0050>, <Players.Lane object at 0x70b1f06e04d0>, <Players.Lane object at 0x70b1f06e0450>, <Players.Lane object at 0x70b1f069b4d0>, <Players.Lane object at 0x70b1f07f9a50>], '9': [<Players.Lane object at 0x70b1f07f8c50>, <Players.Lane object at 0x70b1f0753850>, <Players.Lane object at 0x70b1f07536d0>, <Players.Lane object at 0x70b1f0753350>, <Players.Lane object at 0x70b1f07533d0>]}.
# [INFO] Intersection 11 initialized with these lanes: {'4': [<Players.Lane object at 0x70b1f07535d0>, <Players.Lane object at 0x70b1f0753950>, <Players.Lane object at 0x70b1f07539d0>, <Players.Lane object at 0x70b1f0753e50>, <Players.Lane object at 0x70b1f0753cd0>], '10': [<Players.Lane object at 0x70b1f0753dd0>, <Players.Lane object at 0x70b1f0753d50>, <Players.Lane object at 0x70b1f0753c50>, <Players.Lane object at 0x70b1f0753b50>, <Players.Lane object at 0x70b1f0753550>], '12': [<Players.Lane object at 0x70b1f0753a50>, <Players.Lane object at 0x70b1f0753ed0>, <Players.Lane object at 0x70b1f0753f50>, <Players.Lane object at 0x70b1f0753bd0>, <Players.Lane object at 0x70b1f0753ad0>], '14': [<Players.Lane object at 0x70b1f07538d0>, <Players.Lane object at 0x70b1f07534d0>, <Players.Lane object at 0x70b1f0753450>, <Players.Lane object at 0x70b1f07532d0>, <Players.Lane object at 0x70b1f0753250>]}.
# [INFO] Intersection 9 initialized with these lanes: {'5': [<Players.Lane object at 0x70b1f0753750>, <Players.Lane object at 0x70b1f07537d0>, <Players.Lane object at 0x70b1f0753650>, <Players.Lane object at 0x70b1f0963ed0>, <Players.Lane object at 0x70b1f08ff850>], '8': [<Players.Lane object at 0x70b1f0814c50>, <Players.Lane object at 0x70b1f0814dd0>, <Players.Lane object at 0x70b1f0817550>, <Players.Lane object at 0x70b1f0815d50>, <Players.Lane object at 0x70b1f0816050>], '10': [<Players.Lane object at 0x70b1f08162d0>, <Players.Lane object at 0x70b1f08158d0>, <Players.Lane object at 0x70b1f08144d0>, <Players.Lane object at 0x70b1f0814650>, <Players.Lane object at 0x70b1f0814850>]}.
# [INFO] Intersection 8 initialized with these lanes: {'6': [<Players.Lane object at 0x70b1f08155d0>, <Players.Lane object at 0x70b1f0815050>, <Players.Lane object at 0x70b1f08152d0>, <Players.Lane object at 0x70b1f08036d0>, <Players.Lane object at 0x70b1f0803d50>], '7': [<Players.Lane object at 0x70b1f0803350>, <Players.Lane object at 0x70b1f094d5d0>, <Players.Lane object at 0x70b1f094f950>, <Players.Lane object at 0x70b1f094c5d0>, <Players.Lane object at 0x70b1f094c9d0>], '9': [<Players.Lane object at 0x70b1f094c050>, <Players.Lane object at 0x70b1f094fb50>, <Players.Lane object at 0x70b1f094f650>, <Players.Lane object at 0x70b1f094ca50>, <Players.Lane object at 0x70b1f094f2d0>], '16': [<Players.Lane object at 0x70b1f094e250>, <Players.Lane object at 0x70b1f094e550>, <Players.Lane object at 0x70b1f094e5d0>, <Players.Lane object at 0x70b1f094e4d0>, <Players.Lane object at 0x70b1f094e3d0>]}.
# [INFO] Intersection 7 initialized with these lanes: {'8': [<Players.Lane object at 0x70b1f094d950>, <Players.Lane object at 0x70b1f094d7d0>, <Players.Lane object at 0x70b1f0fd61d0>, <Players.Lane object at 0x70b1f0fd6550>, <Players.Lane object at 0x70b1f0fd6150>], '18': [<Players.Lane object at 0x70b1f0fd7250>, <Players.Lane object at 0x70b1f0fd5750>, <Players.Lane object at 0x70b1f0fd49d0>, <Players.Lane object at 0x70b1f0fd45d0>, <Players.Lane object at 0x70b1f0fd75d0>]}.
# [INFO] Intersection 18 initialized with these lanes: {'7': [<Players.Lane object at 0x70b1f0fd70d0>, <Players.Lane object at 0x70b1f0fd74d0>, <Players.Lane object at 0x70b1f0fd5350>, <Players.Lane object at 0x70b1f0fd64d0>, <Players.Lane object at 0x70b1f0fd6d50>], '16': [<Players.Lane object at 0x70b1f0fd4350>, <Players.Lane object at 0x70b1f0fd4e50>, <Players.Lane object at 0x70b1f0fd7dd0>, <Players.Lane object at 0x70b1f0fd4450>, <Players.Lane object at 0x70b1f0fd5d50>], '20': [<Players.Lane object at 0x70b1f0fd6250>, <Players.Lane object at 0x70b1f0fd53d0>, <Players.Lane object at 0x70b1f0fd5b50>, <Players.Lane object at 0x70b1f0fd7450>, <Players.Lane object at 0x70b1f0fd6dd0>]}.
# [INFO] Intersection 16 initialized with these lanes: {'8': [<Players.Lane object at 0x70b1f1c67e50>, <Players.Lane object at 0x70b1f4f3f7d0>, <Players.Lane object at 0x70b2286204d0>, <Players.Lane object at 0x70b2286202d0>, <Players.Lane object at 0x70b228620d50>], '10': [<Players.Lane object at 0x70b2286209d0>, <Players.Lane object at 0x70b228620950>, <Players.Lane object at 0x70b228620cd0>, <Players.Lane object at 0x70b1f1c03d50>, <Players.Lane object at 0x70b1f1c01e50>], '17': [<Players.Lane object at 0x70b1f1c033d0>, <Players.Lane object at 0x70b1f1c030d0>, <Players.Lane object at 0x70b1f1c03150>, <Players.Lane object at 0x70b1f1c03b50>, <Players.Lane object at 0x70b1f19bf2d0>], '18': [<Players.Lane object at 0x70b1f1afc050>, <Players.Lane object at 0x70b1f1afccd0>, <Players.Lane object at 0x70b1f1afc9d0>, <Players.Lane object at 0x70b1f1afcfd0>, <Players.Lane object at 0x70b1f1afd0d0>]}.
# [INFO] Intersection 10 initialized with these lanes: {'9': [<Players.Lane object at 0x70b1f1b55e50>, <Players.Lane object at 0x70b1f1b55d50>, <Players.Lane object at 0x70b1f1b55dd0>, <Players.Lane object at 0x70b1f1b55cd0>, <Players.Lane object at 0x70b1f1b556d0>], '11': [<Players.Lane object at 0x70b1f1b55650>, <Players.Lane object at 0x70b1f1b56650>, <Players.Lane object at 0x70b1f1b566d0>, <Players.Lane object at 0x70b1f1b56750>, <Players.Lane object at 0x70b1f1b567d0>], '15': [<Players.Lane object at 0x70b1f1b56850>, <Players.Lane object at 0x70b1f1b563d0>, <Players.Lane object at 0x70b1f1b56450>, <Players.Lane object at 0x70b1f1b564d0>, <Players.Lane object at 0x70b1f1b56550>], '16': [<Players.Lane object at 0x70b1f1b565d0>, <Players.Lane object at 0x70b1f1b56150>, <Players.Lane object at 0x70b1f1b561d0>, <Players.Lane object at 0x70b1f1b56250>, <Players.Lane object at 0x70b1f1b562d0>], '17': [<Players.Lane object at 0x70b1f1b56350>, <Players.Lane object at 0x70b1f1b55fd0>, <Players.Lane object at 0x70b1f1b56050>, <Players.Lane object at 0x70b1f1b560d0>, <Players.Lane object at 0x70b1f1b55850>]}.
# [INFO] Intersection 15 initialized with these lanes: {'10': [<Players.Lane object at 0x70b1f05ec350>, <Players.Lane object at 0x70b1f05ec1d0>, <Players.Lane object at 0x70b1f05ec150>, <Players.Lane object at 0x70b1f05ec0d0>, <Players.Lane object at 0x70b1f05ec2d0>], '14': [<Players.Lane object at 0x70b1f05ec3d0>, <Players.Lane object at 0x70b1f05ec450>, <Players.Lane object at 0x70b1f05ec4d0>, <Players.Lane object at 0x70b1f05ec550>, <Players.Lane object at 0x70b1f05ec5d0>], '19': [<Players.Lane object at 0x70b1f05ec650>, <Players.Lane object at 0x70b1f05ec6d0>, <Players.Lane object at 0x70b1f05ec750>, <Players.Lane object at 0x70b1f05ec7d0>, <Players.Lane object at 0x70b1f05ec850>], '22': [<Players.Lane object at 0x70b1f05ec8d0>, <Players.Lane object at 0x70b1f05ec950>, <Players.Lane object at 0x70b1f05ec9d0>, <Players.Lane object at 0x70b1f05eca50>, <Players.Lane object at 0x70b1f05ecad0>]}.
# [INFO] Intersection 17 initialized with these lanes: {'10': [<Players.Lane object at 0x70b1f05eccd0>, <Players.Lane object at 0x70b1f05ecd50>, <Players.Lane object at 0x70b1f05ecdd0>, <Players.Lane object at 0x70b1f05ece50>, <Players.Lane object at 0x70b1f05eced0>], '16': [<Players.Lane object at 0x70b1f05ecf50>, <Players.Lane object at 0x70b1f05ecfd0>, <Players.Lane object at 0x70b1f05ed050>, <Players.Lane object at 0x70b1f05ed0d0>, <Players.Lane object at 0x70b1f05ed150>], '19': [<Players.Lane object at 0x70b1f05ed1d0>, <Players.Lane object at 0x70b1f05ed250>, <Players.Lane object at 0x70b1f05ed2d0>, <Players.Lane object at 0x70b1f05ed350>, <Players.Lane object at 0x70b1f05ed3d0>]}.
# [INFO] Intersection 14 initialized with these lanes: {'11': [<Players.Lane object at 0x70b1f05ed5d0>, <Players.Lane object at 0x70b1f05ed650>, <Players.Lane object at 0x70b1f05ed6d0>, <Players.Lane object at 0x70b1f05ed750>, <Players.Lane object at 0x70b1f05ed7d0>], '15': [<Players.Lane object at 0x70b1f05ed850>, <Players.Lane object at 0x70b1f05ed8d0>, <Players.Lane object at 0x70b1f05ed950>, <Players.Lane object at 0x70b1f05ed9d0>, <Players.Lane object at 0x70b1f05eda50>], '23': [<Players.Lane object at 0x70b1f05edad0>, <Players.Lane object at 0x70b1f05edb50>, <Players.Lane object at 0x70b1f05edbd0>, <Players.Lane object at 0x70b1f05edc50>, <Players.Lane object at 0x70b1f05edcd0>]}.
# [INFO] Intersection 13 initialized with these lanes: {'12': [<Players.Lane object at 0x70b1f05eded0>, <Players.Lane object at 0x70b1f05edf50>, <Players.Lane object at 0x70b1f05edfd0>, <Players.Lane object at 0x70b1f05ee050>, <Players.Lane object at 0x70b1f05ee0d0>], '24': [<Players.Lane object at 0x70b1f05ee150>, <Players.Lane object at 0x70b1f05ee1d0>, <Players.Lane object at 0x70b1f05ee250>, <Players.Lane object at 0x70b1f05ee2d0>, <Players.Lane object at 0x70b1f05ee350>]}.
# [INFO] Intersection 24 initialized with these lanes: {'13': [<Players.Lane object at 0x70b1f05ee550>, <Players.Lane object at 0x70b1f05ee5d0>, <Players.Lane object at 0x70b1f05ee650>, <Players.Lane object at 0x70b1f05ee6d0>, <Players.Lane object at 0x70b1f05ee750>], '21': [<Players.Lane object at 0x70b1f05ee7d0>, <Players.Lane object at 0x70b1f05ee850>, <Players.Lane object at 0x70b1f05ee8d0>, <Players.Lane object at 0x70b1f05ee950>, <Players.Lane object at 0x70b1f05ee9d0>], '23': [<Players.Lane object at 0x70b1f05eea50>, <Players.Lane object at 0x70b1f05eead0>, <Players.Lane object at 0x70b1f05eeb50>, <Players.Lane object at 0x70b1f05eebd0>, <Players.Lane object at 0x70b1f05eec50>]}.
# [INFO] Intersection 23 initialized with these lanes: {'14': [<Players.Lane object at 0x70b1f05eee50>, <Players.Lane object at 0x70b1f05eeed0>, <Players.Lane object at 0x70b1f05eef50>, <Players.Lane object at 0x70b1f05eefd0>, <Players.Lane object at 0x70b1f05ef050>], '22': [<Players.Lane object at 0x70b1f05ef0d0>, <Players.Lane object at 0x70b1f05ef150>, <Players.Lane object at 0x70b1f05ef1d0>, <Players.Lane object at 0x70b1f05ef250>, <Players.Lane object at 0x70b1f05ef2d0>], '24': [<Players.Lane object at 0x70b1f05ef350>, <Players.Lane object at 0x70b1f05ef3d0>, <Players.Lane object at 0x70b1f05ef450>, <Players.Lane object at 0x70b1f05ef4d0>, <Players.Lane object at 0x70b1f05ef550>]}.
# [INFO] Intersection 19 initialized with these lanes: {'15': [<Players.Lane object at 0x70b1f05ef750>, <Players.Lane object at 0x70b1f05ef7d0>, <Players.Lane object at 0x70b1f05ef850>, <Players.Lane object at 0x70b1f05ef8d0>, <Players.Lane object at 0x70b1f05ef950>], '17': [<Players.Lane object at 0x70b1f05ef9d0>, <Players.Lane object at 0x70b1f05efa50>, <Players.Lane object at 0x70b1f05efad0>, <Players.Lane object at 0x70b1f05efb50>, <Players.Lane object at 0x70b1f05efbd0>], '20': [<Players.Lane object at 0x70b1f05efc50>, <Players.Lane object at 0x70b1f05efcd0>, <Players.Lane object at 0x70b1f05efd50>, <Players.Lane object at 0x70b1f05efdd0>, <Players.Lane object at 0x70b1f05efe50>]}.
# [INFO] Intersection 22 initialized with these lanes: {'15': [<Players.Lane object at 0x70b1f0f800d0>, <Players.Lane object at 0x70b1f0f80150>, <Players.Lane object at 0x70b1f0f801d0>, <Players.Lane object at 0x70b1f0f80250>, <Players.Lane object at 0x70b1f0f802d0>], '20': [<Players.Lane object at 0x70b1f0f80350>, <Players.Lane object at 0x70b1f0f803d0>, <Players.Lane object at 0x70b1f0f80450>, <Players.Lane object at 0x70b1f0f804d0>, <Players.Lane object at 0x70b1f0f80550>], '21': [<Players.Lane object at 0x70b1f0f805d0>, <Players.Lane object at 0x70b1f0f80650>, <Players.Lane object at 0x70b1f0f806d0>, <Players.Lane object at 0x70b1f0f80750>, <Players.Lane object at 0x70b1f0f807d0>], '23': [<Players.Lane object at 0x70b1f0f80850>, <Players.Lane object at 0x70b1f0f808d0>, <Players.Lane object at 0x70b1f0f80950>, <Players.Lane object at 0x70b1f0f809d0>, <Players.Lane object at 0x70b1f0f80a50>]}.
# [INFO] Intersection 20 initialized with these lanes: {'18': [<Players.Lane object at 0x70b1f0f80c50>, <Players.Lane object at 0x70b1f0f80cd0>, <Players.Lane object at 0x70b1f0f80d50>, <Players.Lane object at 0x70b1f0f80dd0>, <Players.Lane object at 0x70b1f0f80e50>], '19': [<Players.Lane object at 0x70b1f0f80ed0>, <Players.Lane object at 0x70b1f0f80f50>, <Players.Lane object at 0x70b1f0f80fd0>, <Players.Lane object at 0x70b1f0f81050>, <Players.Lane object at 0x70b1f0f810d0>], '21': [<Players.Lane object at 0x70b1f0f81150>, <Players.Lane object at 0x70b1f0f811d0>, <Players.Lane object at 0x70b1f0f81250>, <Players.Lane object at 0x70b1f0f812d0>, <Players.Lane object at 0x70b1f0f81350>], '22': [<Players.Lane object at 0x70b1f0f813d0>, <Players.Lane object at 0x70b1f0f81450>, <Players.Lane object at 0x70b1f0f814d0>, <Players.Lane object at 0x70b1f0f81550>, <Players.Lane object at 0x70b1f0f815d0>]}.
# [INFO] Intersection 21 initialized with these lanes: {'20': [<Players.Lane object at 0x70b1f0f817d0>, <Players.Lane object at 0x70b1f0f81850>, <Players.Lane object at 0x70b1f0f818d0>, <Players.Lane object at 0x70b1f0f81950>, <Players.Lane object at 0x70b1f0f819d0>], '22': [<Players.Lane object at 0x70b1f0f81a50>, <Players.Lane object at 0x70b1f0f81ad0>, <Players.Lane object at 0x70b1f0f81b50>, <Players.Lane object at 0x70b1f0f81bd0>, <Players.Lane object at 0x70b1f0f81c50>], '24': [<Players.Lane object at 0x70b1f0f81cd0>, <Players.Lane object at 0x70b1f0f81d50>, <Players.Lane object at 0x70b1f0f81dd0>, <Players.Lane object at 0x70b1f0f81e50>, <Players.Lane object at 0x70b1f0f81ed0>]}.
# [INFO] Initializing finished. Graph had been generated.

# %%
output_path = Path(r"/mnt/Data1/Python_Projects/Advanced-Python/Project-02-AV-Simulation/Results")
result = pd.read_csv(output_path / "simulation_log.csv")
result
# Out:
#        time  vehicle_id  origin  destination  lane  block  arrival_time  \
# 0         8           0      16           10     0      0             8
# 1         9           1      16            8     1      0             9
# 2        10           0      16           10     0      1             8
# 3        10           1      16            8     1      1             9
# 4        13           2      24           21     3      0            13
# ...     ...         ...     ...          ...   ...    ...           ...
# 21692   995         262       9           10     3      1           993
# 21693   995         263      10            9     1      1           994
# 21694   995         264       8            7     4      1           995
# 21695   996         265       6            5     3      0           996
# 21696   999         266       1            3     4      0           999
#
#        stuck_time  active light type
# 0               0   False  none  HDV
# 1               0   False  none  HDV
# 2               0   False  none  HDV
# 3               0   False  none  HDV
# 4               0   False  none   AV
# ...           ...     ...   ...  ...
# 21692           0    True  none  HDV
# 21693           0    True  none   AV
# 21694           0    True  none   AV
# 21695           0    True  none  HDV
# 21696           0    True  none   AV
#
# [21697 rows x 11 columns]
